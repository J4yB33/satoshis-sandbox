# %% [markdown]
# # Satoshi’s Sandbox 🏜️ - Cloud Runner
# Run the cells below to launch the Bitcoin Wallet Explorer in the cloud.

# %%
# !git clone https://github.com/J4yB33/satoshis-sandbox.git
# %cd satoshis-sandbox
# !pip install flask requests
# !npm install -g localtunnel

# %%
import threading
from google.colab import output

def run_app():
    # !python3 app.py

thread = threading.Thread(target=run_app)
thread.start()

# This creates the public link for you to click
# !npx localtunnel --port 5000
